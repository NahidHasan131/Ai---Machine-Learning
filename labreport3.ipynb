# %%
D_Section = {
    221311121: {
        "Name": "Nuhan Intekhab",
        "CGPA": 4.00,
        "Cse-321": "A+",
        "Cse-323": "A+",
        "Cse-324": "A+",
        "Eco-331": "A+",
        "Cse-331": "A+",
        "Cse-332": "A+",
        "Cse-333": "A+",
        "Cse-334": "A+",
        "Cse-336": "A+"
    },
    221311123: {
        "Name": "Tasnim Raysa",
        "CGPA": 3.19,
        "Cse-321": "A-",
        "Cse-323": "C+",
        "Cse-324": "A-",
        "Eco-331": "A-",
        "Cse-331": "A",
        "Cse-332": "A",
        "Cse-333": "B",
        "Cse-334": "B",
        "Cse-336": "D"
    },
    221311124: {
        "Name": "Sadiya Promi",
        "CGPA": 3.46,
        "Cse-321": "A+",
        "Cse-323": "B",
        "Cse-324": "B",
        "Eco-331": "A+",
        "Cse-331": "A",
        "Cse-332": "B+",
        "Cse-333": "A-",
        "Cse-334": "B+",
        "Cse-336": "D"
    },
    221311125: {
        "Name": "Fatin Fuad",
        "CGPA": 3.75,
        "Cse-321": "A",
        "Cse-323": "A",
        "Cse-324": "A",
        "Eco-331": "A",
        "Cse-331": "A",
        "Cse-332": "B+",
        "Cse-333": "A",
        "Cse-334": "A",
        "Cse-336": "B"
    },
    221311126: {
        "Name": "Shahriar Fahim",
        "CGPA": 3.67,
        "Cse-321": "A",
        "Cse-323": "A",
        "Cse-324": "A",
        "Eco-331": "A",
        "Cse-331": "A",
        "Cse-332": "A",
        "Cse-333": "A",
        "Cse-334": "A",
        "Cse-336": "B"
    },
    221311127: {
        "Name": "Raunak Aman",
        "CGPA": 3.20,
        "Cse-321": "B",
        "Cse-323": "C+",
        "Cse-324": "A",
        "Eco-331": "A",
        "Cse-331": "A",
        "Cse-332": "A+",
        "Cse-333": "A",
        "Cse-334": "A",
        "Cse-336": "A"
    },
    221311128: {
        "Name": "Md. Ali Sakib",
        "CGPA": 2.90,
        "Cse-321": "F",
        "Cse-323": "C",
        "Cse-324": "B",
        "Eco-331": "B",
        "Cse-331": "B",
        "Cse-332": "A+",
        "Cse-333": "B",
        "Cse-334": "B+",
        "Cse-336": "C"
    },
    221311129: {
        "Name": "Zubair Ifti",
        "CGPA": 3.69,
        "Cse-321": "A-",
        "Cse-323": "B+",
        "Cse-324": "A",
        "Eco-331": "A",
        "Cse-331": "A",
        "Cse-332": "A+",
        "Cse-333": "A+",
        "Cse-334": "A",
        "Cse-336": "A"
    },
    221311130: {
        "Name": "Md. Yousuf Ali",
        "CGPA": 3.68,
        "Cse-321": "A+",
        "Cse-323": "A",
        "Cse-324": "A",
        "Eco-331": "A",
        "Cse-331": "A",
        "Cse-332": "B+",
        "Cse-333": "A",
        "Cse-334": "A",
        "Cse-336": "B"
    },
    221311131: {
        "Name": "Md. Nahid Hasan",
        "CGPA": 4.00,
        "Cse-321": "A+",
        "Cse-323": "A+",
        "Cse-324": "A+",
        "Eco-331": "A+",
        "Cse-331": "A+",
        "Cse-332": "A+",
        "Cse-333": "A+",
        "Cse-334": "A+",
        "Cse-336": "A+"
    },
    221311132: {
        "Name": "Refat-E-Jannat",
        "CGPA": 3.65,
        "Cse-321": "A+",
        "Cse-323": "B",
        "Cse-324": "A",
        "Eco-331": "A",
        "Cse-331": "A+",
        "Cse-332": "A",
        "Cse-333": "A",
        "Cse-334": "A",
        "Cse-336": "A"
    },
    221311133: {
        "Name": "Jinnatun Nesa Jeba",
        "CGPA": 4.00,
        "Cse-321": "A+",
        "Cse-323": "A+",
        "Cse-324": "A+",
        "Eco-331": "A+",
        "Cse-331": "A+",
        "Cse-332": "A+",
        "Cse-333": "A+",
        "Cse-334": "A+",
        "Cse-336": "A+"
    },
    221311135: {
        "Name": "Sadiya Sajnin Tuly",
        "CGPA": 3.92,
        "Cse-321": "A+",
        "Cse-323": "A+",
        "Cse-324": "A+",
        "Eco-331": "A+",
        "Cse-331": "A+",
        "Cse-332": "A+",
        "Cse-333": "A+",
        "Cse-334": "A",
        "Cse-336": "A"
    },
    221311139: {
        "Name": "Homai Ara Yesmin",
        "CGPA": 4.00,
        "Cse-321": "A+",
        "Cse-323": "A+",
        "Cse-324": "A+",
        "Eco-331": "A+",
        "Cse-331": "A+",
        "Cse-332": "A+",
        "Cse-333": "A+",
        "Cse-334": "A+",
        "Cse-336": "A+"
    },
    221311142: {
        "Name": "Naim Akhand",
        "CGPA": 3.72,
        "Cse-321": "A-",
        "Cse-323": "B",
        "Cse-324": "A+",
        "Eco-331": "A+",
        "Cse-331": "A+",
        "Cse-332": "A+",
        "Cse-333": "A+",
        "Cse-334": "A",
        "Cse-336": "A"
    },
    221311143: {
        "Name": "Shahed Rahman",
        "CGPA": 4.00,
        "Cse-321": "A+",
        "Cse-323": "A+",
        "Cse-324": "A+",
        "Eco-331": "A+",
        "Cse-331": "A+",
        "Cse-332": "A+",
        "Cse-333": "A+",
        "Cse-334": "A+",
        "Cse-336": "A+"
    },
    221311144: {
        "Name": "Nafiz Ahmed",
        "CGPA": 3.91,
        "Cse-321": "A+",
        "Cse-323": "A+",
        "Cse-324": "A+",
        "Eco-331": "A+",
        "Cse-331": "A+",
        "Cse-332": "A+",
        "Cse-333": "A+",
        "Cse-334": "A",
        "Cse-336": "A"
    },
    221311145: {
        "Name": "Shrabona Rani Chakraborty",
        "CGPA": 3.89,
        "Cse-321": "A+",
        "Cse-323": "A",
        "Cse-324": "A",
        "Eco-331": "A+",
        "Cse-331": "A+",
        "Cse-332": "A+",
        "Cse-333": "A+",
        "Cse-334": "A",
        "Cse-336": "A"
    },
    221311146: {
        "Name": "Rakibul Haque Sardar",
        "CGPA": 3.72,
        "Cse-321": "A-",
        "Cse-323": "A",
        "Cse-324": "A",
        "Eco-331": "A+",
        "Cse-331": "A+",
        "Cse-332": "A+",
        "Cse-333": "A+",
        "Cse-334": "A",
        "Cse-336": "A"
    },
    221311150: {
        "Name": "Mahfuz Kabir Niloy",
        "CGPA": 4.00,
        "Cse-321": "A+",
        "Cse-323": "A+",
        "Cse-324": "A+",
        "Eco-331": "A+",
        "Cse-331": "A+",
        "Cse-332": "A+",
        "Cse-333": "A+",
        "Cse-334": "A+",
        "Cse-336": "A+"
    },
    221311151: {
        "Name": "Tasfia Islam",
        "CGPA": 3.72,
        "Cse-321": "A-",
        "Cse-323": "A",
        "Cse-324": "A",
        "Eco-331": "A+",
        "Cse-331": "A+",
        "Cse-332": "A+",
        "Cse-333": "A+",
        "Cse-334": "A",
        "Cse-336": "A"
    },
    221311152: {
        "Name": "Sobuji Akter",
        "CGPA": 3.72,
        "Cse-321": "A-",
        "Cse-323": "A",
        "Cse-324": "A",
        "Eco-331": "A+",
        "Cse-331": "A+",
        "Cse-332": "A+",
        "Cse-333": "A+",
        "Cse-334": "A",
        "Cse-336": "A"
    },
    221311154: {
        "Name": "Maruf Zamil",
        "CGPA": 3.72,
        "Cse-321": "A-",
        "Cse-323": "A",
        "Cse-324": "A",
        "Eco-331": "A+",
        "Cse-331": "A+",
        "Cse-332": "A+",
        "Cse-333": "A+",
        "Cse-334": "A",
        "Cse-336": "A"
    },
    221311155: {
        "Name": "Sohanur Rahman",
        "CGPA": 4.00,
        "Cse-321": "A+",
        "Cse-323": "A+",
        "Cse-324": "A+",
        "Eco-331": "A+",
        "Cse-331": "A+",
        "Cse-332": "A+",
        "Cse-333": "A+",
        "Cse-334": "A+",
        "Cse-336": "A+"
    },
    221311156: {
        "Name": "Manowar Hossain Saykat",
        "CGPA": 3.72,
        "Cse-321": "A-",
        "Cse-323": "A",
        "Cse-324": "A",
        "Eco-331": "A+",
        "Cse-331": "A+",
        "Cse-332": "A+",
        "Cse-333": "A+",
        "Cse-334": "A",
        "Cse-336": "A"
    },
    221311157: {
        "Name": "Rayhan Sany",
        "CGPA": 3.72,
        "Cse-321": "A-",
        "Cse-323": "A",
        "Cse-324": "A",
        "Eco-331": "A+",
        "Cse-331": "A+",
        "Cse-332": "A+",
        "Cse-333": "A+",
        "Cse-334": "A",
        "Cse-336": "A"
    },
    221311159: {
        "Name": "Nafisa Anjum",
        "CGPA": 3.81,
        "Cse-321": "A+",
        "Cse-323": "B",
        "Cse-324": "B+",
        "Eco-331": "A+",
        "Cse-331": "A+",
        "Cse-332": "A+",
        "Cse-333": "A+",
        "Cse-334": "A",
        "Cse-336": "A"
    },
    221311160: {
        "Name": "Zeba Tasnia",
        "CGPA": 3.81,
        "Cse-321": "A+",
        "Cse-323": "B",
        "Cse-324": "B+",
        "Eco-331": "A+",
        "Cse-331": "A+",
        "Cse-332": "A+",
        "Cse-333": "A+",
        "Cse-334": "A",
        "Cse-336": "A"
    }
}


course_result = [D_Section[var]["Cse-321"] for var in D_Section]
print("Cse-321 result for all student:",course_result)

student_id = int(input("Enter Student ID: "))

if student_id in D_Section:
    result = D_Section[student_id]["CGPA"] 
    print("Result for",student_id,"is:",result) 
else:
    print("Student ID not found.")
# Out:
# Cse-321 result for all student: ['A+', 'A-', 'A+', 'A', 'A', 'B', 'F', 'A-', 'A+', 'A+', 'A+', 'A+', 'A+', 'A+', 'A-', 'A+', 'A+', 'A+', 'A-', 'A+', 'A-', 'A-', 'A-', 'A+', 'A-', 'A-', 'A+', 'A+']
# Result for 221311132 is: 3.65
